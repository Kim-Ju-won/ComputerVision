# %% [markdown]
# # Assignment#6
#
# ```bash
# 수업 : 컴퓨터 비전(Computer Vision
# 교수님 : 김낙현 교수님
#
# 이름 : 김주원
# 학과 : 컴퓨터전자시스템공학부
# 학번 : 201600765
# 과제제출일 : 2022-05-27
# ```
#
# 1. 강의자료 8-F의 15쪽에 있는 자료에서는 ‘elephant.jpg’ 영상에 대한 실험을 수행하였다. 이와 유사하게 자전거, 자동차, 동물 등 다양한 영상을 5장 수집하여 실험을 수행하여 나오는 결과를 제시하라.
#
# - 실습을 위해 5장의 사진을 Google에서 자동차, 자전거, 호랑이, 사자, 고양이 사진을 수집하여 해당 실습을 진행하였습니다. 실습과 똑같이 ResNet50을 모델로 이용하였고, 샘플 영상을 같은 방식으로 resize하여 예측하였습니다. 아래 내용에서 코드를 확인할 수 있습니다.

# %% [markdown]
# ## 인식 프로그램 호출
# - ImageNet 데이터로 훈련된 신경망을 호출하여 사용할 수 있음
# - 실습에 올라왔던 elephang.jpg를 이용해서 문제를 예측한 모습

# %%
from tensorflow.keras.applications.resnet50 import ResNet50 
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions 
import numpy as np 

model = ResNet50(weights='imagenet') # ImageNet으로 학습된 신경망을 호출
img_path = 'elephant.jpg' # 샘플 영상을 입력. 크기는 관계없음
img = image.load_img(img_path, target_size=(224, 224)) # 영상을 resize 함
x = image.img_to_array(img) 
x = np.expand_dims(x, axis=0) 
x = preprocess_input(x) 

preds = model.predict(x) 
# decode the results into a list of tuples (class, description, probability) 
# (one such list for each sample in the batch) print('Predicted:', decode_predictions(preds, top=3)[0])
decode_predictions(preds, top=3)[0]
# Out:
# ...
# 102981632/102967424 [==============================] - 28s 0us/step
# 2022-05-27 01:17:26.369904: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# [('n02504458', 'African_elephant', 0.95699495),
#  ('n01871265', 'tusker', 0.032436434),
#  ('n02504013', 'Indian_elephant', 0.008768046)]

# %% [markdown]
# ## 1. 자동차 인식 테스트
# - 실습과 같이 ResNet50을 이용해서 진행하였으며, 사진을 (224,224)로 resize해서 진행해주었습니다.
# - 사진이름 : car.jpg
# - 활용한 사진 :
# ![image.png](attachment:image.png)
# - 결과를 확인해보면 자동차를 sports_car(60%), racer(36%)로 분류한 것을 확인할 수 있습니다. 올바르게 인식한 것을 확인할 수 있습니다.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50 
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions 
import numpy as np 

model = ResNet50(weights='imagenet') # ImageNet으로 학습된 신경망을 호출
img_path = 'car.jpg' # 샘플 영상을 입력. 크기는 관계없음
img = image.load_img(img_path, target_size=(224, 224)) # 영상을 resize 함
x = image.img_to_array(img) 
x = np.expand_dims(x, axis=0) 
x = preprocess_input(x) 

preds = model.predict(x) 
# decode the results into a list of tuples (class, description, probability) 
# (one such list for each sample in the batch) print('Predicted:', decode_predictions(preds, top=3)[0])
decode_predictions(preds, top=3)[0]
# Out:
# [('n04285008', 'sports_car', 0.6037133),
#  ('n04037443', 'racer', 0.3613666),
#  ('n02974003', 'car_wheel', 0.01649638)]

# %% [markdown]
# ## 2. 자전거 인식 테스트
# - 실습과 같이 ResNet50을 이용해서 진행하였으며, 사진을 (224,224)로 resize해서 진행해주었습니다.
# - 사진이름 : bycicle.jpg
# - 활용한 사진 :
# ![image.png](attachment:image.png)
# - 결과 : 자전거사진을 bicycle-built-for-two(27%), mountain_bike(8%)로 결과를 낸 것을 확인할 수 있습니다. 실험 중 가장 낮은 확률을 보였으나 올바르게 분류한 것을 확인할 수 있었습니다.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50 
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions 
import numpy as np 

model = ResNet50(weights='imagenet') # ImageNet으로 학습된 신경망을 호출
img_path = 'bycicle.jpg' # 샘플 영상을 입력. 크기는 관계없음
img = image.load_img(img_path, target_size=(224, 224)) # 영상을 resize 함
x = image.img_to_array(img) 
x = np.expand_dims(x, axis=0) 
x = preprocess_input(x) 

preds = model.predict(x) 
# decode the results into a list of tuples (class, description, probability) 
# (one such list for each sample in the batch) print('Predicted:', decode_predictions(preds, top=3)[0])
decode_predictions(preds, top=3)[0]
# Out:
# [('n02835271', 'bicycle-built-for-two', 0.27063096),
#  ('n04482393', 'tricycle', 0.20773022),
#  ('n03792782', 'mountain_bike', 0.08596296)]

# %% [markdown]
# ## 3. 호랑이 인식 테스트
# - 실습과 같이 ResNet50을 이용해서 진행하였으며, 사진을 (224,224)로 resize해서 진행해주었습니다.
# - 사진이름 : Siberia tiger.jpg
# - 활용한 사진 :
# ![image.png](attachment:image.png)
# - 결과 : 96%이상 tiger로 분류한 것을 확인하였습니다. 모든 결과들 중 가장 좋은 정확도를 보였습니다.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50 
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions 
import numpy as np 

model = ResNet50(weights='imagenet') # ImageNet으로 학습된 신경망을 호출
img_path = 'Siberia tiger.jpg' # 샘플 영상을 입력. 크기는 관계없음
img = image.load_img(img_path, target_size=(224, 224)) # 영상을 resize 함
x = image.img_to_array(img) 
x = np.expand_dims(x, axis=0) 
x = preprocess_input(x) 

preds = model.predict(x) 
# decode the results into a list of tuples (class, description, probability) 
# (one such list for each sample in the batch) print('Predicted:', decode_predictions(preds, top=3)[0])
decode_predictions(preds, top=3)[0]
# Out:
# [('n02129604', 'tiger', 0.96100414),
#  ('n02123159', 'tiger_cat', 0.032970138),
#  ('n02127052', 'lynx', 0.0051102685)]

# %% [markdown]
# ## 4. 사자 인식 테스트
# - 실습과 같이 ResNet50을 이용해서 진행하였으며, 사진을 (224,224)로 resize해서 진행해주었습니다.
# - 사진이름 : lion.jpg
# - 활용한 사진 :
# ![image.png](attachment:image.png)
# - 결과 : 사자로 약 58%로 분류했으며, 다른 것으로 분류한것은 5%내외로 이 또한 올바르게 분류했음을 알 수 있었습니다.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50 
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions 
import numpy as np 

model = ResNet50(weights='imagenet') # ImageNet으로 학습된 신경망을 호출
img_path = 'lion.jpg' # 샘플 영상을 입력. 크기는 관계없음
img = image.load_img(img_path, target_size=(224, 224)) # 영상을 resize 함
x = image.img_to_array(img) 
x = np.expand_dims(x, axis=0) 
x = preprocess_input(x) 

preds = model.predict(x) 
# decode the results into a list of tuples (class, description, probability) 
# (one such list for each sample in the batch) print('Predicted:', decode_predictions(preds, top=3)[0])
decode_predictions(preds, top=3)[0]
# Out:
# [('n02129165', 'lion', 0.5839641),
#  ('n02422699', 'impala', 0.04125999),
#  ('n02415577', 'bighorn', 0.020362474)]

# %% [markdown]
# ## 5. 고양이 인식 테스트
# - 실습과 같이 ResNet50을 이용해서 진행하였으며, 사진을 (224,224)로 resize해서 진행해주었습니다.
# - 사진이름 : cat.jpg
# - 활용한 사진 :
# ![image.png](attachment:image.png)
# - 결과 : Egyptian_cat, tabby, lynx 모두 고양이 종류로 고양이라는 것으로 인식했음을 알 수 있었습니다.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50 
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions 
import numpy as np 

model = ResNet50(weights='imagenet') # ImageNet으로 학습된 신경망을 호출
img_path = 'cat.jpg' # 샘플 영상을 입력. 크기는 관계없음
img = image.load_img(img_path, target_size=(224, 224)) # 영상을 resize 함
x = image.img_to_array(img) 
x = np.expand_dims(x, axis=0) 
x = preprocess_input(x) 

preds = model.predict(x) 
# decode the results into a list of tuples (class, description, probability) 
# (one such list for each sample in the batch) print('Predicted:', decode_predictions(preds, top=3)[0])
decode_predictions(preds, top=3)[0]
# Out:
# [('n02124075', 'Egyptian_cat', 0.25201204),
#  ('n02123045', 'tabby', 0.18514013),
#  ('n02127052', 'lynx', 0.09407169)]
